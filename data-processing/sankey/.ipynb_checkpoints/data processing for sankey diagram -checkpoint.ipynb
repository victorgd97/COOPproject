# %% [markdown]
# 4. Canalització
# - Which kind of actors are the leaders of the project? (com es canalitzen els recursos, per tipus d’actor?)
# - Which typology of projects are doing the actors? (com els canalitzen els diferents agents, per tipologies?)

# %% [markdown]
# #### Steps in Sankey
#
# GovLevel -> TipusActor -> Area -> Pais
#
# #### json structure
#
# `[2015, 2016, 2017, 2018]`
#
# each year
#
# `2015:{nodes:[{...}], links:[{...}]}`

# %%
import pandas as pd
import numpy as np
import json

pd.options.display.max_columns = 2000 # remove ellipsis
pd.options.display.max_rows = 2000 # remove ellipsis

# %%
df = pd.read_csv('data/DataPross+Pop+Budgetv2.csv',encoding='latin1', decimal=",")
#df_new = pd.read_excel('data/dataset cooperacio nomes Generalitat 2015-2018.xlsx')

# %%
df.head()
# Out:
#    Index          Modalitat   Any   GovLevel   Institucio InstitucioII  \
# 0      1    Desenvolupament  2016  Municipal  AjBarcelona    Barcelona
# 1      3  Acció_Humanitària  2016  Municipal  AjBarcelona    Barcelona
# 2      4    Desenvolupament  2016  Municipal  AjBarcelona    Barcelona
# 3      5    Desenvolupament  2016  Municipal  AjBarcelona    Barcelona
# 4      6  Acció_Humanitària  2016  Municipal  AjBarcelona    Barcelona
#
#       Codi                                          Entitat  Subvenció  \
# 0  80193.0                               Farmaceutics Mundi  143398.12
# 1  80193.0                              Acció contra la Fam  153500.00
# 2  80193.0  Fundació Montblanc per a la promoció de la dona   57438.68
# 3  80193.0                                   Metges del Món   47440.00
# 4  80193.0                              Acció contra la Fam   57440.00
#
#         Budget  Population                                                CRS  \
# 0  24687931401   1636762.0  15170 - Organitzacions i institucions per la i...
# 1  24687931401   1636762.0               73010 - Ajuda per a la reconstrucció
# 2  24687931401   1636762.0             13040 - Lluita contra ETS, VIH inclosa
# 3  24687931401   1636762.0                               15160 - Drets Humans
# 4  24687931401   1636762.0               73010 - Ajuda per a la reconstrucció
#
#                                             Projecte  \
# 0  Apoyo a restitución integral de los DD de las ...
# 1  Capacidades institucionales y comunitarias par...
# 2  PREVENCIÓ I LLUITA CONTRA LA SIDA A 2 DISTRICT...
# 3                                      LGTBI - Dakar
# 4  Medios de vida productivos para mujeres cabeza...
#
#                                Pais TipusActor Subvenció(TXT)  \
# 0  Democratic Republic of the Congo        ONG   143.398,12 
# 1                         Palestine        ONG   153.500,00 
# 2  Democratic Republic of the Congo        ONG    57.438,68 
# 3                           Senegal        ONG    47.440,00 
# 4                         Palestine        ONG    57.440,00 
#
#                   Area         Ciutat ConcepteFCCD  \
# 0  Africa SudSahariana           Kivu          NaN
# 1         Mediterrania           GAZA          NaN
# 2  Africa SudSahariana  Kinshasa City          NaN
# 3  Africa SudSahariana          Dakar          NaN
# 4         Mediterrania    CISJORDANIA          NaN
#
#                                           Contrapart  SectorCAD   ODS  \
# 0  FEPSI (Femmes Engagées pour la Promotion de la...      151.0   5.0
# 1  Action Against Hunger - Occupied Palestinian T...      740.0  15.0
# 2  ASSOCIATION CENTRE CONGOLAIS DE CULTURE, DE FO...      130.0   5.0
# 3  Association KIRAAY, Association ADAMA, Associa...      151.0   5.0
# 4  Action Against Hunger - Occupied Palestinian T...      740.0  15.0
#
#                            PaisCat   IDH  Index.1
# 0  República Democràtica del Congo  0.43        1
# 1                        Palestina  0.68        3
# 2  República Democràtica del Congo  0.43        4
# 3                          Senegal  0.47        5
# 4                        Palestina  0.68        6

# %%
df[df['Pais'] == 'Catalunya']
# Out:
#       Index          Modalitat   Any   GovLevel   Institucio InstitucioII  \
# 104     139   EpD_i_Capacitats  2015  Municipal  AjBarcelona    Barcelona
# 105     140   EpD_i_Capacitats  2015  Municipal  AjBarcelona    Barcelona
# 106     141   EpD_i_Capacitats  2015  Municipal  AjBarcelona    Barcelona
# 107     142   EpD_i_Capacitats  2015  Municipal  AjBarcelona    Barcelona
# 108     143   EpD_i_Capacitats  2015  Municipal  AjBarcelona    Barcelona
# ...     ...                ...   ...        ...          ...          ...
# 6417   7286   EpD_i_Capacitats  2018  Municipal   Ens Locals         Gavà
# 6418   7287   EpD_i_Capacitats  2018  Municipal   Ens Locals         Gavà
# 6419   7288   EpD_i_Capacitats  2018  Municipal   Ens Locals         Gavà
# 6421   7290  Acció_Humanitària  2018  Municipal   Ens Locals         Gavà
# 6422   7291   EpD_i_Capacitats  2018  Municipal   Ens Locals         Gavà
#
#          Codi                                          Entitat  Subvenció  \
# 104   80193.0                                      Cooperacció    76448.0
# 105   80193.0                                      Entrepobles    58296.0
# 106   80193.0  ODG  Observatori del Deute en la Globalització    76841.0
# 107   80193.0                Universitat Autònoma de Barcelona    79932.0
# 108   80193.0               FETS - Finançament Ètic i Solidari    78476.0
# ...       ...                                              ...        ...
# 6417  80898.0                                              NaN      500.0
# 6418  80898.0                                              NaN    30000.0
# 6419  80898.0                                              NaN    12500.0
# 6421  80898.0                                            ACAPS     3000.0
# 6422  80898.0                                Amical Mauthausen      600.0
#
#            Budget  Population  \
# 104   25725091520   1636762.0
# 105   25725091520   1636762.0
# 106   25725091520   1636762.0
# 107   25725091520   1636762.0
# 108   25725091520   1636762.0
# ...           ...         ...
# 6417    452660733     46771.0
# 6418    452660733     46771.0
# 6419    452660733     46771.0
# 6421    452660733     46771.0
# 6422    452660733     46771.0
#
#                                                     CRS  \
# 104   99820 - Foment de la sensibilització per a la ...
# 105   99820 - Foment de la sensibilització per a la ...
# 106   99820 - Foment de la sensibilització per a la ...
# 107   99820 - Foment de la sensibilització per a la ...
# 108   99820 - Foment de la sensibilització per a la ...
# ...                                                 ...
# 6417  99820 - Foment de la sensibilització per a la ...
# 6418  99820 - Foment de la sensibilització per a la ...
# 6419  99820 - Foment de la sensibilització per a la ...
# 6421            93010 - Refugiats als paísos d'acollida
# 6422  99820 - Foment de la sensibilització per a la ...
#
#                                                Projecte       Pais  \
# 104   Escola Popular d'Economia Feminista: un canvi ...  Catalunya
# 105   Ciutats visibles per a tots i totes: Barcelona...  Catalunya
# 106   La Relocalització energètica a Barcelona.Cap a...  Catalunya
# 107   Impulsant l'educació per al desenvolupament a ...  Catalunya
# 108   L'altra cara de la moneda:implicant joves barc...  Catalunya
# ...                                                 ...        ...
# 6417       Centre de treball persones refugiades a Gavà  Catalunya
# 6418               Sensibilització estacions solidàries  Catalunya
# 6419                     Sensibilització Guia Educativa  Catalunya
# 6421  Vacances en Pau per a infants Sahrauis  Estiu...  Catalunya
# 6422                                      Xarxa Mai Més  Catalunya
#
#         TipusActor Subvenció(TXT)    Area Ciutat ConcepteFCCD Contrapart  \
# 104            ONG    76.448,00   Europa    NaN          NaN        NaN
# 105            ONG    58.296,00   Europa    NaN          NaN        NaN
# 106            ONG    76.841,00   Europa    NaN          NaN        NaN
# 107   Universitats    79.932,00   Europa    NaN          NaN        NaN
# 108            ONG    78.476,00   Europa    NaN          NaN        NaN
# ...            ...            ...     ...    ...          ...        ...
# 6417           NaN       500,00   Europa    NaN          NaN        NaN
# 6418           NaN    30.000,00   Europa    NaN          NaN        NaN
# 6419           NaN    12.500,00   Europa    NaN          NaN        NaN
# 6421           ONG     3.000,00   Europa    NaN          NaN        NaN
# 6422           ONG       600,00   Europa    NaN          NaN        NaN
#
#       SectorCAD   ODS    PaisCat   IDH  Index.1
# 104         NaN   NaN  Catalunya  0.88      139
# 105         NaN   NaN  Catalunya  0.88      140
# 106         NaN   NaN  Catalunya  0.88      141
# 107         NaN   NaN  Catalunya  0.88      142
# 108         NaN   NaN  Catalunya  0.88      143
# ...         ...   ...        ...   ...      ...
# 6417        NaN   NaN  Catalunya  0.88     7286
# 6418        NaN   NaN  Catalunya  0.88     7287
# 6419        NaN   NaN  Catalunya  0.88     7288
# 6421      998.0  17.0  Catalunya  0.88     7290
# 6422        NaN   NaN  Catalunya  0.88     7291
#
# [2889 rows x 25 columns]

# %%
# GovLevel -> TipusActor -> Area -> Pais

def pivoting(year):
    df2 = df[['Any', 'GovLevel', 'TipusActor', 'Area' ,'Pais' , 'Subvenció']].dropna(how='all')
    df2['TipusActor'] = df2['TipusActor'].fillna('Unknown_TipusActor')
    df2['Area'] = df2['Area'].fillna('Unknown_Area')
    
    df3 = df2[df2['Any']==year]
    
    table = pd.pivot_table(df3, values=['Subvenció'], index=['GovLevel', 'TipusActor'],
                    aggfunc={'Subvenció': np.sum}).reset_index()
    table2= pd.pivot_table(df3, values=['Subvenció'], index=['TipusActor', 'Area'],
                    aggfunc={'Subvenció': np.sum}).reset_index()
    table3= pd.pivot_table(df3, values=['Subvenció'], index=['Area', 'Pais'],
                aggfunc={'Subvenció': np.sum}).reset_index()

    return([table, table2, table3])


# Duplicating Area and Pais, add * at the end of Pais  
# helper func1
def area_pais_checking(table):
    comparison_column = np.where(table.iloc[:, 0] == table.iloc[:, 1], True, False)
    table["equal"] = comparison_column
    return table
# helper func2
def duplication_mark(row):
    if row['equal'] == True:
        return row['Pais'] + "*"
    else: 
        return row['Pais']
    
def area_pais(t):
    t= area_pais_checking(t)
    t['Pais'] = t.apply(duplication_mark, axis=1)
    t = t.drop('equal', 1)
    return t

def ordered_unique_nodes(table_list): 
    p = table_list[2].sort_values(['Area', 'Subvenció'], ascending=[True, False])
    pais_order = list(p['Pais'].unique())
    area_order = list(p['Area'].unique())
    tipus = list(table_list[1]['TipusActor'].unique())
    govlevel_order = ['Gene', 'Province', 'Region', 'Municipal']
    nodes_list = govlevel_order + tipus + area_order + pais_order 
    return nodes_list

def nodelink(table_list):
    t1 = table_list[0].rename(columns={"GovLevel": "source", 
                               "TipusActor": "target", 
                               "Subvenció": "value"})
    
    t2 = table_list[1].rename(columns={"TipusActor": "source", 
                                "Area": "target", 
                                "Subvenció": "value"})
    
    t3 = table_list[2].sort_values(['Area', 'Subvenció'], ascending=[True, False])
    
    
    t3 = t3.rename(columns={"Area": "source", 
                                "Pais": "target", 
                                "Subvenció": "value"})

    links = pd.concat([t1, t2, t3], ignore_index=True)
    result = links.to_json(orient="records")
    parsed_links = json.loads(result)
    
    
#     nodes = list(links['target'].unique()) + list(links['source'].unique())
#     nodes_list = list(set(nodes)) 
    
    nodes_list = ordered_unique_nodes(table_list)
    
    nodes_df = pd.DataFrame(nodes_list, columns = ["id"])
    result = nodes_df.to_json(orient="records")
    parsed_nodes = json.loads(result)

    d = { "nodes": parsed_nodes, "links": parsed_links }
    
    return d

# %%
def json_creator(year):
    table_list = pivoting(year)
    table_list[2] = area_pais(table_list[2])
    return nodelink(table_list)

# %%
data_area = {"2015":json_creator(2015), "2016":json_creator(2016), "2017":json_creator(2017), "2018":json_creator(2018)}

# %%
data_area['2015']
# Out:
# {'nodes': [{'id': 'Gene'},
#   {'id': 'Province'},
#   {'id': 'Region'},
#   {'id': 'Municipal'},
#   {'id': 'Administracions catalanes'},
#   {'id': 'Administracions del Sud'},
#   {'id': 'Agent empresarial'},
#   {'id': 'Centre de recerca'},
#   {'id': 'Diversos actors'},
#   {'id': 'Federacions i coordinadores'},
#   {'id': 'Multilaterals'},
#   {'id': 'ONG'},
#   {'id': 'Universitats'},
#   {'id': 'Unknown_TipusActor'},
#   {'id': 'Africa SudSahariana'},
#   {'id': 'America Central i Carib'},
#   {'id': 'America del Sud'},
#   {'id': 'Europa'},
#   {'id': 'Global'},
#   {'id': 'Mediterrania'},
#   {'id': 'Sense Dades'},
#   {'id': 'Àsia'},
#   {'id': 'Mozambique'},
#   {'id': 'Senegal'},
#   {'id': 'Democratic Republic of the Congo'},
#   {'id': 'Mali'},
#   {'id': 'Burkina Faso'},
#   {'id': 'Niger'},
#   {'id': 'Gambia'},
#   {'id': 'Ethiopia'},
#   {'id': 'Cameroon'},
#   {'id': 'Rwanda'},
#   {'id': 'Madagascar'},
#   {'id': 'Ghana'},
#   {'id': 'Equatorial Guinea'},
#   {'id': 'Guinea-Bissau'},
#   {'id': 'Kenya'},
#   {'id': 'Togo'},
#   {'id': 'Malawi'},
#   {'id': "Cote d'Ivoire"},
#   {'id': 'Mauritania'},
#   {'id': 'Gabon'},
#   {'id': 'Angola'},
#   {'id': 'Uganda'},
#   {'id': 'Zimbabwe'},
#   {'id': 'Central African Republic'},
#   {'id': 'El Salvador'},
#   {'id': 'Guatemala'},
#   {'id': 'Nicaragua'},
#   {'id': 'Cuba'},
#   {'id': 'America Central i Carib*'},
#   {'id': 'Mexico'},
#   {'id': 'Honduras'},
#   {'id': 'Dominican Republic'},
#   {'id': 'Costa Rica'},
#   {'id': 'Panama'},
#   {'id': 'Haiti'},
#   {'id': 'Colombia'},
#   {'id': 'Bolivia'},
#   {'id': 'Ecuador'},
#   {'id': 'Peru'},
#   {'id': 'Chile'},
#   {'id': 'Argentina'},
#   {'id': 'Brazil'},
#   {'id': 'Venezuela'},
#   {'id': 'Paraguay'},
#   {'id': 'Uruguay'},
#   {'id': 'Catalunya'},
#   {'id': 'Bosnia and Herzegovina'},
#   {'id': 'Greece'},
#   {'id': 'Serbia'},
#   {'id': 'Global'},
#   {'id': 'Global*'},
#   {'id': 'Palestine'},
#   {'id': 'Lebanon'},
#   {'id': 'Morocco'},
#   {'id': 'Mediterrania*'},
#   {'id': 'Western Sahara'},
#   {'id': 'Turkey'},
#   {'id': 'Jordan'},
#   {'id': 'Syrian Arab Republic'},
#   {'id': 'Tunisia'},
#   {'id': 'Algeria'},
#   {'id': 'Libyan Arab Jamahiriya'},
#   {'id': 'Egypt'},
#   {'id': 'Sense Dades*'},
#   {'id': 'India'},
#   {'id': 'China'},
#   {'id': 'Iran (Islamic Republic of)'},
#   {'id': 'Ukraine'},
#   {'id': 'Pakistan'},
#   {'id': 'Cambodia'},
#   {'id': 'Bangladesh'},
#   {'id': 'Nepal'},
#   {'id': 'Yemen'},
#   {'id': 'Philippines'},
#   {'id': 'Sri Lanka'},
#   {'id': 'Georgia'},
#   {'id': 'Malaysia'}],
#  'links': [{'source': 'Gene',
#    'target': 'Administracions catalanes',
#    'value': 7354085.430000001},
#   {'source': 'Gene', 'target': 'Administracions del Sud', 'value': 425983.93},
#   {'source': 'Gene', 'target': 'Centre de recerca', 'value': 1226032.0},
#   {'source': 'Gene', 'target': 'Diversos actors', 'value': 1591939.8},
#   {'source': 'Gene',
#    'target': 'Federacions i coordinadores',
#    'value': 250000.0},
#   {'source': 'Gene', 'target': 'Multilaterals', 'value': 1582383.4},
#   {'source': 'Gene', 'target': 'ONG', 'value': 3432151.17},
#   {'source': 'Gene', 'target': 'Universitats', 'value': 526975.0},
#   {'source': 'Gene', 'target': 'Unknown_TipusActor', 'value': 89905.2},
#   {'source': 'Municipal',
#    'target': 'Administracions catalanes',
#    'value': 150464.12},
#   {'source': 'Municipal',
#    'target': 'Administracions del Sud',
#    'value': 33274.0},
#   {'source': 'Municipal', 'target': 'Agent empresarial', 'value': 204081.0},
#   {'source': 'Municipal', 'target': 'Diversos actors', 'value': 182065.72},
#   {'source': 'Municipal',
#    'target': 'Federacions i coordinadores',
#    'value': 259529.0},
#   {'source': 'Municipal', 'target': 'Multilaterals', 'value': 430942.0},
#   {'source': 'Municipal', 'target': 'ONG', 'value': 11011613.080000004},
#   {'source': 'Municipal', 'target': 'Universitats', 'value': 21000.0},
#   {'source': 'Municipal',
#    'target': 'Unknown_TipusActor',
#    'value': 6644666.9700000025},
#   {'source': 'Province',
#    'target': 'Administracions catalanes',
#    'value': 73000.0},
#   {'source': 'Province', 'target': 'Diversos actors', 'value': 207540.0},
#   {'source': 'Province', 'target': 'ONG', 'value': 86699.0},
#   {'source': 'Province', 'target': 'Universitats', 'value': 11214.52},
#   {'source': 'Province',
#    'target': 'Unknown_TipusActor',
#    'value': 2982410.670000001},
#   {'source': 'Region', 'target': 'ONG', 'value': 12743.0},
#   {'source': 'Region', 'target': 'Unknown_TipusActor', 'value': 16115.77},
#   {'source': 'Administracions catalanes',
#    'target': 'Africa SudSahariana',
#    'value': 295844.54},
#   {'source': 'Administracions catalanes',
#    'target': 'America Central i Carib',
#    'value': 401414.2700000001},
#   {'source': 'Administracions catalanes',
#    'target': 'America del Sud',
#    'value': 749651.55},
#   {'source': 'Administracions catalanes',
#    'target': 'Europa',
#    'value': 4817355.4399999995},
#   {'source': 'Administracions catalanes',
#    'target': 'Global',
#    'value': 128277.25},
#   {'source': 'Administracions catalanes',
#    'target': 'Mediterrania',
#    'value': 247192.29},
#   {'source': 'Administracions catalanes',
#    'target': 'Àsia',
#    'value': 937814.2100000001},
#   {'source': 'Administracions del Sud',
#    'target': 'Africa SudSahariana',
#    'value': 90000.0},
#   {'source': 'Administracions del Sud',
#    'target': 'America Central i Carib',
#    'value': 28973.0},
#   {'source': 'Administracions del Sud',
#    'target': 'America del Sud',
#    'value': 251309.0},
#   {'source': 'Administracions del Sud', 'target': 'Europa', 'value': 4301.0},
#   {'source': 'Administracions del Sud',
#    'target': 'Mediterrania',
#    'value': 84674.93},
#   {'source': 'Agent empresarial',
#    'target': 'Africa SudSahariana',
#    'value': 75940.0},
#   {'source': 'Agent empresarial', 'target': 'Europa', 'value': 128141.0},
#   {'source': 'Centre de recerca',
#    'target': 'Africa SudSahariana',
#    'value': 50000.0},
#   {'source': 'Centre de recerca', 'target': 'Europa', 'value': 1126032.0},
#   {'source': 'Centre de recerca', 'target': 'Mediterrania', 'value': 50000.0},
#   {'source': 'Diversos actors',
#    'target': 'Africa SudSahariana',
#    'value': 27195.0},
#   {'source': 'Diversos actors',
#    'target': 'America Central i Carib',
#    'value': 67390.0},
#   {'source': 'Diversos actors', 'target': 'America del Sud', 'value': 16515.0},
#   {'source': 'Diversos actors',
#    'target': 'Europa',
#    'value': 1840109.7200000002},
#   {'source': 'Diversos actors', 'target': 'Mediterrania', 'value': 18070.8},
#   {'source': 'Diversos actors', 'target': 'Àsia', 'value': 12265.0},
#   {'source': 'Federacions i coordinadores',
#    'target': 'Europa',
#    'value': 509529.0},
#   {'source': 'Multilaterals',
#    'target': 'America Central i Carib',
#    'value': 20000.0},
#   {'source': 'Multilaterals', 'target': 'America del Sud', 'value': 50000.0},
#   {'source': 'Multilaterals', 'target': 'Europa', 'value': 1142050.4},
#   {'source': 'Multilaterals', 'target': 'Global', 'value': 184775.0},
#   {'source': 'Multilaterals', 'target': 'Mediterrania', 'value': 616500.0},
#   {'source': 'ONG',
#    'target': 'Africa SudSahariana',
#    'value': 2911894.1400000006},
#   {'source': 'ONG', 'target': 'America Central i Carib', 'value': 2794517.12},
#   {'source': 'ONG', 'target': 'America del Sud', 'value': 2428770.6399999997},
#   {'source': 'ONG', 'target': 'Europa', 'value': 3496345.61},
#   {'source': 'ONG', 'target': 'Global', 'value': 37056.57},
#   {'source': 'ONG', 'target': 'Mediterrania', 'value': 2428580.54},
#   {'source': 'ONG', 'target': 'Àsia', 'value': 446041.63},
#   {'source': 'Universitats', 'target': 'Europa', 'value': 439189.52},
#   {'source': 'Universitats', 'target': 'Global', 'value': 120000.0},
#   {'source': 'Unknown_TipusActor',
#    'target': 'Africa SudSahariana',
#    'value': 320042.24},
#   {'source': 'Unknown_TipusActor',
#    'target': 'America Central i Carib',
#    'value': 533509.71},
#   {'source': 'Unknown_TipusActor',
#    'target': 'America del Sud',
#    'value': 827028.15},
#   {'source': 'Unknown_TipusActor', 'target': 'Europa', 'value': 3906341.02},
#   {'source': 'Unknown_TipusActor', 'target': 'Global', 'value': 192138.26},
#   {'source': 'Unknown_TipusActor',
#    'target': 'Mediterrania',
#    'value': 809938.5699999998},
#   {'source': 'Unknown_TipusActor',
#    'target': 'Sense Dades',
#    'value': 3130710.41},
#   {'source': 'Unknown_TipusActor', 'target': 'Àsia', 'value': 13390.25},
#   {'source': 'Africa SudSahariana',
#    'target': 'Mozambique',
#    'value': 1016380.26},
#   {'source': 'Africa SudSahariana',
#    'target': 'Senegal',
#    'value': 962322.6900000001},
#   {'source': 'Africa SudSahariana',
#    'target': 'Democratic Republic of the Congo',
#    'value': 464803.35},
#   {'source': 'Africa SudSahariana', 'target': 'Mali', 'value': 289006.86},
#   {'source': 'Africa SudSahariana',
#    'target': 'Burkina Faso',
#    'value': 234789.34},
#   {'source': 'Africa SudSahariana', 'target': 'Niger', 'value': 179594.97},
#   {'source': 'Africa SudSahariana', 'target': 'Gambia', 'value': 125032.99},
#   {'source': 'Africa SudSahariana', 'target': 'Ethiopia', 'value': 124059.09},
#   {'source': 'Africa SudSahariana', 'target': 'Cameroon', 'value': 78369.88},
#   {'source': 'Africa SudSahariana', 'target': 'Rwanda', 'value': 46090.0},
#   {'source': 'Africa SudSahariana', 'target': 'Madagascar', 'value': 38979.0},
#   {'source': 'Africa SudSahariana', 'target': 'Ghana', 'value': 31649.28},
#   {'source': 'Africa SudSahariana',
#    'target': 'Equatorial Guinea',
#    'value': 28218.0},
#   {'source': 'Africa SudSahariana',
#    'target': 'Guinea-Bissau',
#    'value': 24762.0},
#   {'source': 'Africa SudSahariana', 'target': 'Kenya', 'value': 22557.0},
#   {'source': 'Africa SudSahariana', 'target': 'Togo', 'value': 17275.0},
#   {'source': 'Africa SudSahariana', 'target': 'Malawi', 'value': 15387.0},
#   {'source': 'Africa SudSahariana',
#    'target': "Cote d'Ivoire",
#    'value': 14999.86},
#   {'source': 'Africa SudSahariana', 'target': 'Mauritania', 'value': 14905.1},
#   {'source': 'Africa SudSahariana', 'target': 'Gabon', 'value': 14809.97},
#   {'source': 'Africa SudSahariana', 'target': 'Angola', 'value': 10000.0},
#   {'source': 'Africa SudSahariana', 'target': 'Uganda', 'value': 8821.0},
#   {'source': 'Africa SudSahariana', 'target': 'Zimbabwe', 'value': 6603.28},
#   {'source': 'Africa SudSahariana',
#    'target': 'Central African Republic',
#    'value': 1500.0},
#   {'source': 'America Central i Carib',
#    'target': 'El Salvador',
#    'value': 985970.36},
#   {'source': 'America Central i Carib',
#    'target': 'Guatemala',
#    'value': 833510.7100000002},
#   {'source': 'America Central i Carib',
#    'target': 'Nicaragua',
#    'value': 722261.96},
#   {'source': 'America Central i Carib', 'target': 'Cuba', 'value': 481579.0},
#   {'source': 'America Central i Carib',
#    'target': 'America Central i Carib*',
#    'value': 366814.71},
#   {'source': 'America Central i Carib', 'target': 'Mexico', 'value': 229692.7},
#   {'source': 'America Central i Carib',
#    'target': 'Honduras',
#    'value': 88771.5},
#   {'source': 'America Central i Carib',
#    'target': 'Dominican Republic',
#    'value': 39994.58},
#   {'source': 'America Central i Carib',
#    'target': 'Costa Rica',
#    'value': 38822.3},
#   {'source': 'America Central i Carib', 'target': 'Panama', 'value': 32011.28},
#   {'source': 'America Central i Carib', 'target': 'Haiti', 'value': 26375.0},
#   {'source': 'America del Sud', 'target': 'Colombia', 'value': 1894883.1},
#   {'source': 'America del Sud',
#    'target': 'Bolivia',
#    'value': 791901.1799999999},
#   {'source': 'America del Sud', 'target': 'Ecuador', 'value': 709575.23},
#   {'source': 'America del Sud', 'target': 'Peru', 'value': 493720.46},
#   {'source': 'America del Sud', 'target': 'Chile', 'value': 110166.07},
#   {'source': 'America del Sud', 'target': 'Argentina', 'value': 96861.44},
#   {'source': 'America del Sud', 'target': 'Brazil', 'value': 86447.16},
#   {'source': 'America del Sud', 'target': 'Venezuela', 'value': 51657.48},
#   {'source': 'America del Sud', 'target': 'Paraguay', 'value': 49135.22},
#   {'source': 'America del Sud', 'target': 'Uruguay', 'value': 38927.0},
#   {'source': 'Europa', 'target': 'Catalunya', 'value': 17278232.99999999},
#   {'source': 'Europa', 'target': 'Bosnia and Herzegovina', 'value': 65000.0},
#   {'source': 'Europa', 'target': 'Greece', 'value': 42390.0},
#   {'source': 'Europa', 'target': 'Serbia', 'value': 23591.71},
#   {'source': 'Europa', 'target': 'Global', 'value': 180.0},
#   {'source': 'Global', 'target': 'Global*', 'value': 662247.0800000001},
#   {'source': 'Mediterrania',
#    'target': 'Palestine',
#    'value': 954733.7000000001},
#   {'source': 'Mediterrania', 'target': 'Lebanon', 'value': 926249.6299999999},
#   {'source': 'Mediterrania', 'target': 'Morocco', 'value': 840239.2099999998},
#   {'source': 'Mediterrania', 'target': 'Mediterrania*', 'value': 430969.0},
#   {'source': 'Mediterrania', 'target': 'Western Sahara', 'value': 234878.32},
#   {'source': 'Mediterrania', 'target': 'Turkey', 'value': 234226.99},
#   {'source': 'Mediterrania', 'target': 'Jordan', 'value': 217972.68},
#   {'source': 'Mediterrania',
#    'target': 'Syrian Arab Republic',
#    'value': 175899.0},
#   {'source': 'Mediterrania', 'target': 'Tunisia', 'value': 88990.8},
#   {'source': 'Mediterrania', 'target': 'Algeria', 'value': 60156.79},
#   {'source': 'Mediterrania',
#    'target': 'Libyan Arab Jamahiriya',
#    'value': 50069.0},
#   {'source': 'Mediterrania', 'target': 'Egypt', 'value': 40572.01},
#   {'source': 'Sense Dades', 'target': 'Sense Dades*', 'value': 3130710.41},
#   {'source': 'Àsia', 'target': 'India', 'value': 641845.35},
#   {'source': 'Àsia', 'target': 'China', 'value': 215692.98},
#   {'source': 'Àsia',
#    'target': 'Iran (Islamic Republic of)',
#    'value': 185137.34},
#   {'source': 'Àsia', 'target': 'Ukraine', 'value': 93989.48},
#   {'source': 'Àsia', 'target': 'Pakistan', 'value': 79919.84},
#   {'source': 'Àsia', 'target': 'Cambodia', 'value': 49682.87},
#   {'source': 'Àsia', 'target': 'Bangladesh', 'value': 48597.7},
#   {'source': 'Àsia', 'target': 'Nepal', 'value': 41828.43},
#   {'source': 'Àsia', 'target': 'Yemen', 'value': 20083.3},
#   {'source': 'Àsia', 'target': 'Philippines', 'value': 11347.0},
#   {'source': 'Àsia', 'target': 'Sri Lanka', 'value': 10755.0},
#   {'source': 'Àsia', 'target': 'Georgia', 'value': 10230.68},
#   {'source': 'Àsia', 'target': 'Malaysia', 'value': 401.12}]}

# %%
with open("output/data.json", "w") as outfile: 
    json.dump(data_area, outfile)

# %%
with open("output/data2015.json", "w") as outfile: 
    json.dump(data_area['2015'], outfile)

# %%
with open("output/data2018.json", "w") as outfile: 
    json.dump(data_area['2018'], outfile)
